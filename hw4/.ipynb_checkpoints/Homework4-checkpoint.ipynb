# %%
import numpy as np 
import pandas as pd
import random
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,KFold
import sklearn.model_selection as skl_model
from sklearn.preprocessing import OneHotEncoder
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %% [markdown]
# ## 1. Linear Regression using a simple perceptron
#
# ### For  getting  into  graduate  school,  download  the grad school attribute data set from Files.

# %% [markdown]
# #### a) Define the features that are related to predicting the Chance of Admit, and normalize them.

# %%
df = pd.read_csv("Admission_Predict_Ver1.1.csv")
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# drop the serial number
df = df.drop("Serial No.", axis=1)
chance = df["Chance of Admit "]
df = df.drop("Chance of Admit ", axis=1)
#normalize the rest of the data 
df = (df - df.mean()) / df.std()
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating       SOP      LOR       CGPA  \
# 0   1.817417     1.777086           0.774806  1.136222  1.097845  1.775029
# 1   0.666481    -0.031569           0.774806  0.631683  1.097845  0.485373
# 2  -0.041788    -0.524839          -0.099693 -0.377395  0.017289 -0.953088
# 3   0.489414     0.461700          -0.099693  0.127144 -1.063267  0.154692
# 4  -0.218855    -0.689262          -0.974192 -1.386473 -0.522989 -0.605873
#
#    Research
# 0  0.885518
# 1  0.885518
# 2  0.885518
# 3  0.885518
# 4 -1.127023

# %% [markdown]
# ####  b) Fill in the code for a simple perceptron. Initialize your weights and biases between 0 and 0.05 using your random number generator. Use the mean squares error (MSE) to adjust your weights through back-propagation. Fill in the blanks for the feedforward and backpropagation step.

# %%
class simple_perceptron():
    def __init__(self,input_dim,output_dim,learning_rate=0.01,activation=lambda x:x,activation_grad=lambda x:1):
        
        self.input_dim=input_dim
        self.output_dim=output_dim
        self.activation=activation
        self.activation_grad=activation_grad
        self.lr=learning_rate
        ### initialize weights between 0 and 0.05 ###
        self.weights=np.random.rand(input_dim,output_dim)*0.05
        self.biases=np.random.rand(1,output_dim)*0.05
        
    def predict(self,X):
        if len(X.shape)==1:
            X=X.reshape((-1,1))
        dim=X.shape[1]
        # Check that the dimension of accepted input data is the same as expected
        if not dim==self.input_dim:
            raise Exception("Expected input size %d, accepted %d!"%(self.input_dim,dim))
        ### Calculate logit and activation ### 
        self.z=X.dot(self.weights)+self.biases
        self.a=self.activation(self.z)
        return self.a
    
    def fit(self,X,y):
        # Transform the single-sample data into 2-dimensional, for the convenience of matrix multiplication
        if len(X.shape)==1:
            X=X.reshape((-1,1))
        if len(y.shape)==1:
            y=y.reshape((-1,1))
        self.predict(X)
        errors=(self.a-y)*self.activation_grad(self.z)
        weights_grad=errors.T.dot(X)
        bias_grad=np.sum(errors,axis=0)
        ### Update weights and biases from the gradient ###
        self.weights -= weights_grad.T*self.lr
        self.biases -= bias_grad*self.lr
        
    def train_on_epoch(self,X,y,batch_size=32):
        # Every time select batch_size samples from the training set, until all data in the training set has been trained once
        order=list(range(X.shape[0]))
        random.shuffle(order)
        n=0
        while n<math.ceil(len(order)/batch_size)-1: # Parts that can fill one batch
            self.fit(X[order[n*batch_size:(n+1)*batch_size]],y[order[n*batch_size:(n+1)*batch_size]])
            n+=1
        # Parts that cannot fill one batch
        self.fit(X[order[n*batch_size:]],y[order[n*batch_size:]])
        
    def evaluate(self,X,y):
         # Transform the single-sample data into 2-dimensional
        if len(X.shape)==1:
            X=X.reshape((1,-1))
        if len(y.shape)==1:
            y=y.reshape((1,-1))
        ### means square error ###
        return np.mean((self.predict(X)-y)**2)
    
    def get_weights(self):
        return (self.weights,self.biases)
    
    def set_weights(self,weights):
        self.weights=weights[0]
        self.biases=weights[1]

# %% [markdown]
# #### c) Fill in the code for k-fold validation. Use 80% of the data for training and 20% of the data for testing and do 5-fold validation. Use a learning rate of 0.0001. Are the features good indicators for getting into graduate school? Now remove the GRE scores and do the same test; are GRE scores important?

# %%
def Kfold(k,Xs,ys,epochs,learning_rate=0.0001,draw_curve=False):
    # The total number of examples for training the network
    total_num=len(Xs)
    
    # Built in K-fold function in Sci-Kit Learn
    kf=KFold(n_splits=k,shuffle=True)
    # record error for each model
    train_error_all=[]
    test_error_all=[]
    
    for train_selector,test_selector in kf.split(range(total_num)):
        ### Decide training examples and testing examples for this fold ###
        train_Xs=Xs[train_selector]
        test_Xs=Xs[test_selector]
        train_ys=ys[train_selector]
        test_ys=ys[test_selector]

    val_array=[]
    # Split training examples further into training and validation
    train_in,val_in,train_real,val_real=train_test_split(train_Xs,train_ys)
        
    ### Establish the model for simple perceptron here ###
    model=simple_perceptron(Xs.shape[1], 1, learning_rate=learning_rate)
        
    # Save the lowest weights, so that we can recover the best model
    weights = model.get_weights()
    lowest_val_err = np.inf
    for _ in range(epochs):
        # Train model on a number of epochs, and test performance in the validation set
        model.train_on_epoch(train_in,train_real)
        val_err = model.evaluate(val_in,val_real)
        val_array.append(val_err)
        if val_err < lowest_val_err:
            lowest_val_err = val_err
            weights = model.get_weights()
        # The final number of epochs is when the minimum error in validation set occurs    
        final_epochs=np.argmin(val_array)+1
        print("Number of epochs with lowest validation:",final_epochs)
        # Recover the model weight
        model.set_weights(weights)

        # Report result for this fold
        train_error=model.evaluate(train_Xs,train_ys)
        train_error_all.append(train_error)
        test_error=model.evaluate(test_Xs,test_ys)
        test_error_all.append(test_error)
        print("Train error:",train_error)
        print("Test error:",test_error)
        
        if draw_curve:
            plt.figure()
            plt.plot(np.arange(len(val_array))+1,val_array,label='Validation loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.legend()
            
    print("Final results:")
    print("Training error:%f+-%f"%(np.average(train_error_all),np.std(train_error_all)))
    print("Testing error:%f+-%f"%(np.average(test_error_all),np.std(test_error_all)))
    
    # return the last model
    return model

# %%
def show_correlation(xs,ys):
    plt.figure()
    plt.scatter(xs,ys,s=0.5)
    r = [np.min([np.min(xs),np.min(ys)]),np.max([np.max(xs),np.max(ys)])]
    plt.plot(r,r,'r')
    plt.xlabel("Predictions")
    plt.ylabel("Ground truth")
    corr=np.corrcoef([xs,ys])[1,0]
    print("Correlation coefficient:",corr)

# %% [markdown]
# #### Testing the code above. Please note that I have assigned False to draw curve because my jupyter notebook kept crashing

# %%
import sklearn.model_selection as skl_model
Xs = df.to_numpy() 
ys = chance.to_numpy()

train_feat,test_feat,train_ranking,test_ranking=skl_model.train_test_split(Xs, ys, test_size = 0.20)
res = Kfold(k=5, Xs=train_feat, ys=train_ranking, epochs=1000)
# Out:
# Number of epochs with lowest validation: 1
# Train error: 0.5270166307157261
# Test error: 0.5337397908318257
# Number of epochs with lowest validation: 2
# Train error: 0.5047387640916025
# Test error: 0.5121574461255333
# Number of epochs with lowest validation: 3
# Train error: 0.4834924120397273
# Test error: 0.4915065622835508
# Number of epochs with lowest validation: 4
# Train error: 0.4631898958349122
# Test error: 0.4716883119145267
# Number of epochs with lowest validation: 5
# Train error: 0.4438544380434648
# Test error: 0.4527853553026307
# Number of epochs with lowest validation: 6
# Train error: 0.42537611345076093
# Test error: 0.4346460851098549
# Number of epochs with lowest validation: 7
# Train error: 0.407740557351851
# Test error: 0.41728675757107697
# Number of epochs with lowest validation: 8
# Train error: 0.3908987167169507
# Test error: 0.40066304664218777
# Number of epochs with lowest validation: 9
# Train error: 0.37475708514326106
# Test error: 0.3846458055901454
# Number of epochs with lowest validation: 10
# Train error: 0.359434255536907
# Test error: 0.3694711673322514
# Number of epochs with lowest validation: 11
# Train error: 0.34475977359228444
# Test error: 0.3548735123173566
# Number of epochs with lowest validation: 12
# Train error: 0.33073893241949726
# Test error: 0.3408912081797594
# Number of epochs with lowest validation: 13
# Train error: 0.317345353904654
# Test error: 0.327503913480887
# Number of epochs with lowest validation: 14
# Train error: 0.30453907105353734
# Test error: 0.3146688091741386
# Number of epochs with lowest validation: 15
# Train error: 0.2923654211136436
# Test error: 0.3024830298041317
# Number of epochs with lowest validation: 16
# Train error: 0.2806968268233241
# Test error: 0.29075360496361397
# Number of epochs with lowest validation: 17
# Train error: 0.26954864171223397
# Test error: 0.27952705384398074
# Number of epochs with lowest validation: 18
# Train error: 0.25893052362185626
# Test error: 0.26883429231741884
# Number of epochs with lowest validation: 19
# Train error: 0.24881571641000033
# Test error: 0.25864538618274835
# Number of epochs with lowest validation: 20
# Train error: 0.23913213732584432
# Test error: 0.24886432437402498
# Number of epochs with lowest validation: 21
# Train error: 0.2298751151131218
# Test error: 0.2394939832437567
# Number of epochs with lowest validation: 22
# Train error: 0.2210483863689403
# Test error: 0.23055482541167102
# Number of epochs with lowest validation: 23
# Train error: 0.21265211971231257
# Test error: 0.2220573288379655
# Number of epochs with lowest validation: 24
# Train error: 0.20465366388741255
# Test error: 0.21396195720045902
# Number of epochs with lowest validation: 25
# Train error: 0.19698641982083054
# Test error: 0.206176367380818
# Number of epochs with lowest validation: 26
# Train error: 0.189682225544694
# Test error: 0.1987590345264244
# Number of epochs with lowest validation: 27
# Train error: 0.18274484561185136
# Test error: 0.1917228201084633
# Number of epochs with lowest validation: 28
# Train error: 0.1760778463810259
# Test error: 0.18493271514108606
# Number of epochs with lowest validation: 29
# Train error: 0.16974905904902357
# Test error: 0.17849652364556107
# Number of epochs with lowest validation: 30
# Train error: 0.16368613121572534
# Test error: 0.17231533579004035
# Number of epochs with lowest validation: 31
# Train error: 0.157900692782678
# Test error: 0.16641143073270698
# Number of epochs with lowest validation: 32
# Train error: 0.15240799604037888
# Test error: 0.16081360516136706
# Number of epochs with lowest validation: 33
# Train error: 0.14714162603362335
# Test error: 0.15543166364033656
# Number of epochs with lowest validation: 34
# Train error: 0.14211669525432735
# Test error: 0.15029189896271705
# Number of epochs with lowest validation: 35
# Train error: 0.13732533817522063
# Test error: 0.14539022227371753
# Number of epochs with lowest validation: 36
# Train error: 0.132749084173215
# Test error: 0.14070210065284536
# Number of epochs with lowest validation: 37
# Train error: 0.128397640032218
# Test error: 0.13624686671520977
# Number of epochs with lowest validation: 38
# Train error: 0.12422124773423059
# Test error: 0.1319585273698954
# Number of epochs with lowest validation: 39
# Train error: 0.12024889775156751
# Test error: 0.1278823293754633
# Number of epochs with lowest validation: 40
# Train error: 0.11648565948570538
# Test error: 0.1240272988853332
# Number of epochs with lowest validation: 41
# Train error: 0.1128734763450359
# Test error: 0.12031682719555387
# Number of epochs with lowest validation: 42
# Train error: 0.10943382794415857
# Test error: 0.11678283346036263
# Number of epochs with lowest validation: 43
# Train error: 0.10612003571214913
# Test error: 0.11336458963520162
# Number of epochs with lowest validation: 44
# Train error: 0.10299425327792865
# Test error: 0.11015139447809313
# Number of epochs with lowest validation: 45
# Train error: 0.10001117953402798
# Test error: 0.10708157175503016
# Number of epochs with lowest validation: 46
# Train error: 0.09714888619700418
# Test error: 0.10412840976575807
# Number of epochs with lowest validation: 47
# Train error: 0.09442225952609345
# Test error: 0.1013147477595507
# Number of epochs with lowest validation: 48
# Train error: 0.09182297700452992
# Test error: 0.09863137579565194
# Number of epochs with lowest validation: 49
# Train error: 0.08934211936336699
# Test error: 0.09606824937627674
# Number of epochs with lowest validation: 50
# Train error: 0.08698905445528203
# Test error: 0.09363979738464556
# Number of epochs with lowest validation: 51
# Train error: 0.08473913117540556
# Test error: 0.09131450465635037
# Number of epochs with lowest validation: 52
# Train error: 0.08258451100856039
# Test error: 0.08908346257231042
# Number of epochs with lowest validation: 53
# Train error: 0.08052709523832481
# Test error: 0.08695117220862066
# Number of epochs with lowest validation: 54
# Train error: 0.0785687419319993
# Test error: 0.08492180533097336
# Number of epochs with lowest validation: 55
# Train error: 0.07669996983871717
# Test error: 0.08298331209160673
# Number of epochs with lowest validation: 56
# Train error: 0.07492724393323265
# Test error: 0.08114600527131825
# Number of epochs with lowest validation: 57
# Train error: 0.07322237311320362
# Test error: 0.07937397597236967
# Number of epochs with lowest validation: 58
# Train error: 0.07158970405516493
# Test error: 0.07767405141408118
# Number of epochs with lowest validation: 59
# Train error: 0.07004025826420757
# Test error: 0.07606190688486053
# Number of epochs with lowest validation: 60
# Train error: 0.06854651005123928
# Test error: 0.07450225622139124
# Number of epochs with lowest validation: 61
# Train error: 0.0671398178690692
# Test error: 0.07303722628441521
# Number of epochs with lowest validation: 62
# Train error: 0.06578956357189304
# Test error: 0.07162773761936289
# Number of epochs with lowest validation: 63
# Train error: 0.06450381920370406
# Test error: 0.07028531699591145
# Number of epochs with lowest validation: 64
# Train error: 0.06327860111903971
# Test error: 0.06900525439923003
# Number of epochs with lowest validation: 65
# Train error: 0.06210160609012328
# Test error: 0.06777259744131783
# Number of epochs with lowest validation: 66
# Train error: 0.060978947146936475
# Test error: 0.06659621854025373
# Number of epochs with lowest validation: 67
# Train error: 0.05991546801954843
# Test error: 0.0654826323189348
# Number of epochs with lowest validation: 68
# Train error: 0.0588873365294401
# Test error: 0.06440219539421854
# Number of epochs with lowest validation: 69
# Train error: 0.057916474257861374
# Test error: 0.06338327467375855
# Number of epochs with lowest validation: 70
# Train error: 0.056992727821002676
# Test error: 0.06241346305970844
# Number of epochs with lowest validation: 71
# Train error: 0.05611161055581776
# Test error: 0.06148781167688442
# Number of epochs with lowest validation: 72
# Train error: 0.05526297901357464
# Test error: 0.06059353954236801
# Number of epochs with lowest validation: 73
# Train error: 0.05444511790075139
# Test error: 0.05972918770245566
# Number of epochs with lowest validation: 74
# Train error: 0.05368634659291859
# Test error: 0.05893104330276087
# Number of epochs with lowest validation: 75
# Train error: 0.05295015739086764
# Test error: 0.058153349456487986
# Number of epochs with lowest validation: 76
# Train error: 0.05223680895480115
# Test error: 0.057396764180019794
# Number of epochs with lowest validation: 77
# Train error: 0.05156718559747366
# Test error: 0.05668818050850669
# Number of epochs with lowest validation: 78
# Train error: 0.05093618331720149
# Test error: 0.05602131655536013
# Number of epochs with lowest validation: 79
# Train error: 0.050327086493654596
# Test error: 0.05537556920983989
# Number of epochs with lowest validation: 80
# Train error: 0.04973695032798953
# Test error: 0.05474757784895875
# Number of epochs with lowest validation: 81
# Train error: 0.04917533734056644
# Test error: 0.05414959214442141
# Number of epochs with lowest validation: 82
# Train error: 0.04863696431201113
# Test error: 0.05357536484178783
# Number of epochs with lowest validation: 83
# Train error: 0.048135279320852896
# Test error: 0.053041745295524335
# Number of epochs with lowest validation: 84
# Train error: 0.04765273449035781
# Test error: 0.0525272795493231
# Number of epochs with lowest validation: 85
# Train error: 0.047177976138469954
# Test error: 0.05201805161886163
# Number of epochs with lowest validation: 86
# Train error: 0.046738243331931814
# Test error: 0.05154801588693689
# Number of epochs with lowest validation: 87
# Train error: 0.04631616711686599
# Test error: 0.05109594876332535
# Number of epochs with lowest validation: 88
# Train error: 0.04590436421941138
# Test error: 0.050652917004544315
# Number of epochs with lowest validation: 89
# Train error: 0.04551138973580246
# Test error: 0.05022963427142003
# Number of epochs with lowest validation: 90
# Train error: 0.04514112144162132
# Test error: 0.04983096315720104
# Number of epochs with lowest validation: 91
# Train error: 0.04478619241265267
# Test error: 0.049448167792842626
# Number of epochs with lowest validation: 92
# Train error: 0.04444608925531957
# Test error: 0.049080792571947904
# Number of epochs with lowest validation: 93
# Train error: 0.04411740836311589
# Test error: 0.0487245618509239
# Number of epochs with lowest validation: 94
# Train error: 0.043813985534322544
# Test error: 0.048396718241650254
# Number of epochs with lowest validation: 95
# Train error: 0.04351206074852861
# Test error: 0.04806836095972363
# Number of epochs with lowest validation: 96
# Train error: 0.0432314509239232
# Test error: 0.04776375371763736
# Number of epochs with lowest validation: 97
# Train error: 0.042960823446270995
# Test error: 0.047469168815134834
# Number of epochs with lowest validation: 98
# Train error: 0.042698094707238406
# Test error: 0.047182170388010605
# Number of epochs with lowest validation: 99
# Train error: 0.04245211531807995
# Test error: 0.046913706497645674
# Number of epochs with lowest validation: 100
# Train error: 0.04222009068315181
# Test error: 0.04666042335351205
# Number of epochs with lowest validation: 101
# Train error: 0.041997720500016246
# Test error: 0.04641716782057454
# Number of epochs with lowest validation: 102
# Train error: 0.041785960441845196
# Test error: 0.046185077777238986
# Number of epochs with lowest validation: 103
# Train error: 0.041580065881134436
# Test error: 0.045958708891205936
# Number of epochs with lowest validation: 104
# Train error: 0.04138749482266764
# Test error: 0.04574708876360059
# Number of epochs with lowest validation: 105
# Train error: 0.04119866076742393
# Test error: 0.045538663578457025
# Number of epochs with lowest validation: 106
# Train error: 0.04101103586168076
# Test error: 0.045330479413554725
# Number of epochs with lowest validation: 107
# Train error: 0.040838455187757035
# Test error: 0.045139200177088445
# Number of epochs with lowest validation: 108
# Train error: 0.0406771527060383
# Test error: 0.044960470747677755
# Number of epochs with lowest validation: 109
# Train error: 0.040517121815161206
# Test error: 0.04478225399504151
# Number of epochs with lowest validation: 110
# Train error: 0.04036611378886941
# Test error: 0.04461388465000016
# Number of epochs with lowest validation: 111
# Train error: 0.040217202218521736
# Test error: 0.04444714830098321
# Number of epochs with lowest validation: 112
# Train error: 0.04007687342818606
# Test error: 0.04428979714577848
# Number of epochs with lowest validation: 113
# Train error: 0.0399503473817147
# Test error: 0.04414823860844152
# Number of epochs with lowest validation: 114
# Train error: 0.039819387761713135
# Test error: 0.04400066130410262
# Number of epochs with lowest validation: 115
# Train error: 0.03970128575233074
# Test error: 0.04386768557099483
# Number of epochs with lowest validation: 116
# Train error: 0.03958606139647781
# Test error: 0.04373753635437503
# Number of epochs with lowest validation: 117
# Train error: 0.0394788935260768
# Test error: 0.043616437858130075
# Number of epochs with lowest validation: 118
# Train error: 0.03936740629609577
# Test error: 0.04348955365179048
# Number of epochs with lowest validation: 119
# Train error: 0.03926284183825957
# Test error: 0.04337031848836677
# Number of epochs with lowest validation: 120
# Train error: 0.03917022204257772
# Test error: 0.0432647820382979
# Number of epochs with lowest validation: 121
# Train error: 0.03907458742550614
# Test error: 0.043155228826452056
# Number of epochs with lowest validation: 122
# Train error: 0.03898310459855553
# Test error: 0.043050239789801596
# Number of epochs with lowest validation: 123
# Train error: 0.038897810527304885
# Test error: 0.042952124853551654
# Number of epochs with lowest validation: 124
# Train error: 0.03881633246996929
# Test error: 0.04285809520300764
# Number of epochs with lowest validation: 125
# Train error: 0.03874273151955605
# Test error: 0.042773097474373516
# Number of epochs with lowest validation: 126
# Train error: 0.03867002171871738
# Test error: 0.042688758703785995
# Number of epochs with lowest validation: 127
# Train error: 0.03859625508243788
# Test error: 0.04260284366714206
# Number of epochs with lowest validation: 128
# Train error: 0.038528019010715474
# Test error: 0.042523146707660366
# Number of epochs with lowest validation: 129
# Train error: 0.038459007418614764
# Test error: 0.04244228892642769
# Number of epochs with lowest validation: 130
# Train error: 0.038394200971287214
# Test error: 0.042366094279374565
# Number of epochs with lowest validation: 131
# Train error: 0.03833570904768488
# Test error: 0.042297108777753785
# Test error: 0.04092420483901675
# Number of epochs with lowest validation: 165
# Train error: 0.03721158676112522
# Test error: 0.04089709995874223
# Number of epochs with lowest validation: 166
# Train error: 0.03720367583265556
# Test error: 0.040884424422277424
# Number of epochs with lowest validation: 167
# Train error: 0.03718448482522532
# Test error: 0.04085872873400371
# Number of epochs with lowest validation: 168
# Train error: 0.03716555962270393
# Test error: 0.04083337396768967
# Number of epochs with lowest validation: 169
# Train error: 0.03715452016309497
# Test error: 0.040817093276239495
# Number of epochs with lowest validation: 170
# Train error: 0.037144121957174356
# Test error: 0.04080154054547855
# Number of epochs with lowest validation: 171
# Train error: 0.03713256038354793
# Test error: 0.040784666412359026
# Number of epochs with lowest validation: 172
# Train error: 0.03712172622737507
# Test error: 0.0407686250249105
# Number of epochs with lowest validation: 173
# Train error: 0.03711876569581977
# Test error: 0.04076169649268063
# Number of epochs with lowest validation: 174
# Train error: 0.03710762084207809
# Test error: 0.04074529596134515
# Number of epochs with lowest validation: 175
# Train error: 0.037097299601508316
# Test error: 0.04072988612851315
# Number of epochs with lowest validation: 176
# Train error: 0.03708577203646854
# Test error: 0.040713113782266976
# Number of epochs with lowest validation: 177
# Train error: 0.0370751059623508
# Test error: 0.0406973199378907
# Number of epochs with lowest validation: 178
# Train error: 0.03706305924781776
# Test error: 0.04067996175763868
# Number of epochs with lowest validation: 179
# Train error: 0.037048626239554
# Test error: 0.0406598488774988
# Number of epochs with lowest validation: 180
# Train error: 0.0370394714137332
# Test error: 0.04064585261994443
# Number of epochs with lowest validation: 181
# Train error: 0.03702708735418782
# Test error: 0.04062813720619584
# Number of epochs with lowest validation: 182
# Train error: 0.03701618223307259
# Test error: 0.040612149156861434
# Number of epochs with lowest validation: 183
# Train error: 0.0370061229323241
# Test error: 0.04059713481649202
# Number of epochs with lowest validation: 184
# Train error: 0.03700331935762189
# Test error: 0.04059048254173388
# Number of epochs with lowest validation: 185
# Train error: 0.03699380185550274
# Test error: 0.04057614735591869
# Number of epochs with lowest validation: 186
# Train error: 0.036982501730095145
# Test error: 0.04055973993727141
# Number of epochs with lowest validation: 187
# Train error: 0.03697579097165118
# Test error: 0.04054865148408626
# Number of epochs with lowest validation: 188
# Train error: 0.036971014639176784
# Test error: 0.04053979860389208
# Number of epochs with lowest validation: 189
# Train error: 0.0369603584624797
# Test error: 0.040524201752925294
# Number of epochs with lowest validation: 190
# Train error: 0.03695327371131123
# Test error: 0.04051273989275314
# Number of epochs with lowest validation: 191
# Train error: 0.03694911561756433
# Test error: 0.04050465344480411
# Number of epochs with lowest validation: 192
# Train error: 0.03694505418725393
# Test error: 0.040496651260373856
# Number of epochs with lowest validation: 193
# Train error: 0.03694184563604412
# Test error: 0.040489650856924214
# Number of epochs with lowest validation: 194
# Train error: 0.036938985541797115
# Test error: 0.04048308091120347
# Number of epochs with lowest validation: 195
# Train error: 0.036929536063190625
# Test error: 0.04046893441759027
# Number of epochs with lowest validation: 196
# Train error: 0.03692181834261896
# Test error: 0.040456756874642334
# Number of epochs with lowest validation: 197
# Train error: 0.03691552482677625
# Test error: 0.04044632257409887
# Number of epochs with lowest validation: 198
# Train error: 0.03691254964896912
# Test error: 0.04043970454596458
# Number of epochs with lowest validation: 199
# Train error: 0.036907660659752616
# Test error: 0.04043089109792986
# Number of epochs with lowest validation: 200
# Train error: 0.036899563562427434
# Test error: 0.040418399924318525
# Number of epochs with lowest validation: 201
# Train error: 0.03689637475679667
# Test error: 0.04041153410822315
# Number of epochs with lowest validation: 201
# Train error: 0.03689955003824546
# Test error: 0.04041199793977235
# Number of epochs with lowest validation: 201
# Train error: 0.03689990362026683
# Test error: 0.040409240061393945
# Number of epochs with lowest validation: 204
# Train error: 0.03689381389009382
# Test error: 0.04039914164918893
# Number of epochs with lowest validation: 205
# Train error: 0.03688825191937556
# Test error: 0.04038963269446236
# Number of epochs with lowest validation: 206
# Train error: 0.03688167387866526
# Test error: 0.04037896439237322
# Number of epochs with lowest validation: 207
# Train error: 0.03688254940724604
# Test error: 0.040376876950016
# Number of epochs with lowest validation: 208
# Train error: 0.03687902718874422
# Test error: 0.0403697655346901
# Number of epochs with lowest validation: 209
# Train error: 0.03687104749086918
# Test error: 0.040357552237222524
# Number of epochs with lowest validation: 210
# Train error: 0.03686475451775729
# Test error: 0.04034730833011135
# Number of epochs with lowest validation: 211
# Train error: 0.0368636654092314
# Test error: 0.04034301442520329
# Number of epochs with lowest validation: 212
# Train error: 0.03685683526056541
# Test error: 0.04033216979903157
# Number of epochs with lowest validation: 213
# Train error: 0.03685601344498975
# Test error: 0.040328207621341414
# Number of epochs with lowest validation: 214
# Train error: 0.036850637323507594
# Test error: 0.040319102072920145
# Number of epochs with lowest validation: 215
# Train error: 0.03684649619299764
# Test error: 0.040311431521200945
# Number of epochs with lowest validation: 216
# Train error: 0.036845326157053125
# Test error: 0.04030713715588237
# Number of epochs with lowest validation: 217
# Train error: 0.03684150067097855
# Test error: 0.040299843058934144
# Number of epochs with lowest validation: 218
# Train error: 0.036834197173955016
# Test error: 0.040288557364417346
# Number of epochs with lowest validation: 218
# Train error: 0.03683960784740837
# Test error: 0.04029183376123004
# Number of epochs with lowest validation: 218
# Train error: 0.036836965106599825
# Test error: 0.04028593586473621
# Number of epochs with lowest validation: 221
# Train error: 0.03683272262291869
# Test error: 0.04027819710758398
# Number of epochs with lowest validation: 222
# Train error: 0.03683255904023631
# Test error: 0.04027515826756555
# Number of epochs with lowest validation: 223
# Train error: 0.0368277953309488
# Test error: 0.04026688275329557
# Number of epochs with lowest validation: 224
# Train error: 0.03682636830592041
# Test error: 0.04026243679636247
# Number of epochs with lowest validation: 225
# Train error: 0.036821521301233326
# Test error: 0.04025409459091055
# Number of epochs with lowest validation: 226
# Train error: 0.03682091238874419
# Test error: 0.04025062488590369
# Number of epochs with lowest validation: 227
# Train error: 0.036815326693235596
# Test error: 0.040241432706807315
# Number of epochs with lowest validation: 228
# Train error: 0.03681273540319693
# Test error: 0.04023570805766691
# Number of epochs with lowest validation: 229
# Train error: 0.036807631876880985
# Test error: 0.040227130330119536
# Number of epochs with lowest validation: 229
# Train error: 0.03680882527291164
# Test error: 0.039976657607024964
# Number of epochs with lowest validation: 313
# Train error: 0.03677522290384578
# Test error: 0.03997572258528734
# Number of epochs with lowest validation: 313
# Train error: 0.03677410528986662
# Test error: 0.039972808385040165
# Number of epochs with lowest validation: 313
# Train error: 0.03677273700407305
# Test error: 0.039969646770218144
# Number of epochs with lowest validation: 313
# Train error: 0.03677385994052538
# Test error: 0.03996930969871668
# Number of epochs with lowest validation: 313
# Train error: 0.036770643550848414
# Test error: 0.03996407481251028
# Number of epochs with lowest validation: 313
# Train error: 0.03676890071605181
# Test error: 0.039960508752626495
# Number of epochs with lowest validation: 313
# Train error: 0.03676635951483685
# Test error: 0.03995608350545089
# Number of epochs with lowest validation: 337
# Train error: 0.03676405821090198
# Test error: 0.03995191489620725
# Number of epochs with lowest validation: 338
# Train error: 0.03676320386774136
# Test error: 0.039949387657751766
# Number of epochs with lowest validation: 339
# Train error: 0.03676121144700564
# Test error: 0.039945570397294745
# Number of epochs with lowest validation: 340
# Train error: 0.03675859953171205
# Test error: 0.03994108695891148
# Number of epochs with lowest validation: 341
# Train error: 0.03675764698172834
# Test error: 0.039938473950891486
# Number of epochs with lowest validation: 341
# Train error: 0.036759410597664514
# Test error: 0.039938909405793324
# Number of epochs with lowest validation: 341
# Train error: 0.03676464311975343
# Test error: 0.039943356798105845
# Number of epochs with lowest validation: 341
# Train error: 0.036770414993333764
# Test error: 0.039948361635112416
# Number of epochs with lowest validation: 341
# Train error: 0.0367714275862562
# Test error: 0.03994798359301484
# Number of epochs with lowest validation: 341
# Train error: 0.036771121668544696
# Test error: 0.039946164990869365
# Number of epochs with lowest validation: 341
# Train error: 0.036769496147338994
# Test error: 0.039942873910013256
# Number of epochs with lowest validation: 341
# Train error: 0.0367706391029697
# Test error: 0.039942678539774346
# Number of epochs with lowest validation: 341
# Train error: 0.03676924190473668
# Test error: 0.03993964005178707
# Number of epochs with lowest validation: 341
# Train error: 0.03676924656412186
# Test error: 0.03993818642110328
# Number of epochs with lowest validation: 341
# Train error: 0.03677175598408047
# Test error: 0.03993954991547993
# Number of epochs with lowest validation: 341
# Train error: 0.03676963384999075
# Test error: 0.039935734695405914
# Number of epochs with lowest validation: 341
# Train error: 0.0367735226872091
# Test error: 0.03993869381391802
# Number of epochs with lowest validation: 341
# Train error: 0.03677763480279489
# Test error: 0.03994188023897098
# Number of epochs with lowest validation: 341
# Train error: 0.03677532627967072
# Test error: 0.039937858887427645
# Number of epochs with lowest validation: 341
# Train error: 0.03677564787157595
# Test error: 0.03993680356196
# Number of epochs with lowest validation: 341
# Train error: 0.03677563165662574
# Test error: 0.03993536100597327
# Number of epochs with lowest validation: 341
# Train error: 0.03677566708949662
# Test error: 0.03993400506585792
# Number of epochs with lowest validation: 341
# Train error: 0.03677031721996464
# Test error: 0.03992660165388136
# Number of epochs with lowest validation: 341
# Train error: 0.036775780342467174
# Test error: 0.03993140130920342
# Number of epochs with lowest validation: 341
# Train error: 0.03677889218640514
# Test error: 0.03993351122882852
# Number of epochs with lowest validation: 341
# Train error: 0.03678618050231891
# Test error: 0.03989412864634769
# Number of epochs with lowest validation: 390
# Train error: 0.036782392513850556
# Test error: 0.03989335569373943
# Number of epochs with lowest validation: 390
# Train error: 0.036783062773625266
# Test error: 0.039892964667970536
# Number of epochs with lowest validation: 390
# Train error: 0.036782068636900964
# Test error: 0.03989073111125736
# Number of epochs with lowest validation: 390
# Train error: 0.036784782957449656
# Test error: 0.03989268882376893
# Number of epochs with lowest validation: 390
# Train error: 0.03678502262892184
# Test error: 0.03989186786511181
# Number of epochs with lowest validation: 390
# Train error: 0.03678121921579527
# Test error: 0.03988646632758594
# Number of epochs with lowest validation: 390
# Train error: 0.03677775068652756
# Test error: 0.0398814772594737
# Number of epochs with lowest validation: 403
# Train error: 0.036775531757674715
# Test error: 0.03987789736067361
# Number of epochs with lowest validation: 403
# Train error: 0.036781492659997354
# Test error: 0.03988353439679107
# Number of epochs with lowest validation: 403
# Train error: 0.0367847990729513
# Test error: 0.039886157268791314
# Number of epochs with lowest validation: 403
# Train error: 0.03678730590923044
# Test error: 0.03988794090449755
# Number of epochs with lowest validation: 403
# Train error: 0.03679227126087098
# Test error: 0.03989246543113456
# Number of epochs with lowest validation: 403
# Train error: 0.03679135286734926
# Test error: 0.03989036259721356
# Number of epochs with lowest validation: 403
# Train error: 0.036795965958487414
# Test error: 0.0398944832369339
# Number of epochs with lowest validation: 403
# Train error: 0.03679575601836225
# Test error: 0.03989321027474812
# Number of epochs with lowest validation: 403
# Train error: 0.03679524625596611
# Test error: 0.03989155213446605
# Number of epochs with lowest validation: 403
# Train error: 0.03679258157153312
# Test error: 0.039887492043651065
# Number of epochs with lowest validation: 403
# Train error: 0.03678962474344697
# Test error: 0.03988307658420031
# Number of epochs with lowest validation: 403
# Train error: 0.03678781735383863
# Test error: 0.03988002985876406
# Number of epochs with lowest validation: 403
# Train error: 0.03679121362353286
# Test error: 0.03988284134818552
# Number of epochs with lowest validation: 403
# Train error: 0.036789294291580996
# Test error: 0.03987967219181772
# Number of epochs with lowest validation: 403
# Train error: 0.03679154094733496
# Test error: 0.03988117925198928
# Number of epochs with lowest validation: 403
# Train error: 0.036792153562819126
# Test error: 0.03988083837856813
# Number of epochs with lowest validation: 403
# Train error: 0.036792037236276935
# Test error: 0.039879685476081575
# Number of epochs with lowest validation: 403
# Train error: 0.03678865834673424
# Test error: 0.039874883456567096
# Number of epochs with lowest validation: 403
# Train error: 0.03678592679207593
# Test error: 0.03987078958511797
# Number of epochs with lowest validation: 403
# Train error: 0.03678891179341757
# Test error: 0.03987316728920967
# Number of epochs with lowest validation: 403
# Train error: 0.036789963805527265
# Test error: 0.03987336191917825
# Number of epochs with lowest validation: 403
# Train error: 0.03679001598926247
# Test error: 0.03987243400541032
# Number of epochs with lowest validation: 403
# Train error: 0.036792307206231306
# Test error: 0.03987402316751574
# Number of epochs with lowest validation: 403
# Train error: 0.03679738080231889
# Test error: 0.039878740144692636
# Number of epochs with lowest validation: 403
# Train error: 0.036797874112320134
# Test error: 0.03987830586099741
# Number of epochs with lowest validation: 403
# Train error: 0.03679525426408483
# Train error: 0.03689298242693998
# Test error: 0.03981465052852446
# Number of epochs with lowest validation: 608
# Train error: 0.036894323998786865
# Test error: 0.03981611687736768
# Number of epochs with lowest validation: 608
# Train error: 0.036888434732017826
# Test error: 0.039809512148077215
# Number of epochs with lowest validation: 608
# Train error: 0.03689033833142188
# Test error: 0.039811563915762564
# Number of epochs with lowest validation: 608
# Train error: 0.03688912602706708
# Test error: 0.03981014017994588
# Number of epochs with lowest validation: 608
# Train error: 0.036891745737982026
# Test error: 0.039812994620349235
# Number of epochs with lowest validation: 608
# Train error: 0.0368923599828123
# Test error: 0.03981362719791446
# Number of epochs with lowest validation: 608
# Train error: 0.036895494427091356
# Test error: 0.03981705928853782
# Number of epochs with lowest validation: 608
# Train error: 0.036891549515069934
# Test error: 0.03981263684176183
# Number of epochs with lowest validation: 608
# Train error: 0.036890980857371795
# Test error: 0.0398119800930501
# Number of epochs with lowest validation: 608
# Train error: 0.03689247525964582
# Test error: 0.039813606629224646
# Number of epochs with lowest validation: 608
# Train error: 0.03689166524097072
# Test error: 0.039812651452600385
# Number of epochs with lowest validation: 608
# Train error: 0.03689499856726376
# Test error: 0.03981629411739787
# Number of epochs with lowest validation: 608
# Train error: 0.0368950439043297
# Test error: 0.03981629335020378
# Number of epochs with lowest validation: 608
# Train error: 0.036897624966631674
# Test error: 0.03981910846844735
# Number of epochs with lowest validation: 608
# Train error: 0.03689320041203262
# Test error: 0.03981408118767926
# Number of epochs with lowest validation: 608
# Train error: 0.03689460372577947
# Test error: 0.039815603434282476
# Number of epochs with lowest validation: 608
# Train error: 0.03688883964163298
# Test error: 0.03980914201764309
# Number of epochs with lowest validation: 608
# Train error: 0.036885905151238504
# Test error: 0.03980580497806002
# Number of epochs with lowest validation: 608
# Train error: 0.036890375904010626
# Test error: 0.039810752257615795
# Number of epochs with lowest validation: 608
# Train error: 0.03689103177063087
# Test error: 0.03981141606541132
# Final results:
# Training error:0.047655+-0.050857
# Testing error:0.051170+-0.051942

# %%
prediction = res.predict(test_feat)
test_ranking.reshape(100,1)
show_correlation(prediction, test_ranking)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 prediction = res.predict(test_feat)
#       2 test_ranking.reshape(100,1)
# ----> 3 show_correlation(prediction, test_ranking)
#
# Cell In[6], line 8, in show_correlation(xs, ys)
#       6 plt.xlabel("Predictions")
#       7 plt.ylabel("Ground truth")
# ----> 8 corr=np.corrcoef([xs,ys])[1,0]
#       9 print("Correlation coefficient:",corr)
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File ~/CHEM277B/msse/lib/python3.10/site-packages/numpy/lib/function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File ~/CHEM277B/msse/lib/python3.10/site-packages/numpy/lib/function_base.py:2616, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2612     raise ValueError(
#    2613         "ddof must be integer")
#    2615 # Handles complex arrays too
# -> 2616 m = np.asarray(m)
#    2617 if m.ndim > 2:
#    2618     raise ValueError("m has more than 2 dimensions")
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 100) + inhomogeneous part.

# %% [markdown]
# #### Removing GRE scores and then testing the above code

# %%
df = df.drop("GRE Score", axis=1)
Xs = df.to_numpy() 
ys = chance.to_numpy()

train_feat,test_feat,train_ranking,test_ranking=skl_model.train_test_split(Xs, ys, test_size = 0.20)
res = Kfold(k=5, Xs=train_feat, ys=train_ranking, epochs=1000)
# Out:
# Number of epochs with lowest validation: 1
# Train error: 0.4835221771125241
# Test error: 0.4525505259145335
# Number of epochs with lowest validation: 2
# Train error: 0.46255539257106704
# Test error: 0.4325639090444405
# Number of epochs with lowest validation: 3
# Train error: 0.4425653730033964
# Test error: 0.4135058189987795
# Number of epochs with lowest validation: 4
# Train error: 0.42349908959467614
# Test error: 0.3953250499390189
# Number of epochs with lowest validation: 5
# Train error: 0.40537540927575777
# Test error: 0.3780518204551172
# Number of epochs with lowest validation: 6
# Train error: 0.38806979064720487
# Test error: 0.36155138271663245
# Number of epochs with lowest validation: 7
# Train error: 0.37158808006011257
# Test error: 0.3458385421589899
# Number of epochs with lowest validation: 8
# Train error: 0.3558910081406623
# Test error: 0.3308778119105942
# Number of epochs with lowest validation: 9
# Train error: 0.34090384060236795
# Test error: 0.3165904722005156
# Number of epochs with lowest validation: 10
# Train error: 0.3266303204020986
# Test error: 0.3029867433685691
# Number of epochs with lowest validation: 11
# Train error: 0.31303567287663564
# Test error: 0.29003360045807236
# Number of epochs with lowest validation: 12
# Train error: 0.30011394740937564
# Test error: 0.2777301013746186
# Number of epochs with lowest validation: 13
# Train error: 0.2877547911691088
# Test error: 0.2659572382761455
# Number of epochs with lowest validation: 14
# Train error: 0.2760131322358609
# Test error: 0.254781701384182
# Number of epochs with lowest validation: 15
# Train error: 0.26480090670312095
# Test error: 0.24410900464247548
# Number of epochs with lowest validation: 16
# Train error: 0.25412326781298783
# Test error: 0.23394925371848876
# Number of epochs with lowest validation: 17
# Train error: 0.2439794762932281
# Test error: 0.22430418716132194
# Number of epochs with lowest validation: 18
# Train error: 0.23424624775371453
# Test error: 0.21504569105290705
# Number of epochs with lowest validation: 19
# Train error: 0.22497613523674875
# Test error: 0.20623159231024948
# Number of epochs with lowest validation: 20
# Train error: 0.21617055472354046
# Test error: 0.19786569634500017
# Number of epochs with lowest validation: 21
# Train error: 0.2077989191616734
# Test error: 0.18991811808686876
# Number of epochs with lowest validation: 22
# Train error: 0.19979312862967885
# Test error: 0.1823184448820762
# Number of epochs with lowest validation: 23
# Train error: 0.19219637465601436
# Test error: 0.175113820207965
# Number of epochs with lowest validation: 24
# Train error: 0.18493088369360194
# Test error: 0.16822439193679348
# Number of epochs with lowest validation: 25
# Train error: 0.17800532275885167
# Test error: 0.16166077556778952
# Number of epochs with lowest validation: 26
# Train error: 0.17142775638636545
# Test error: 0.15543260570551737
# Number of epochs with lowest validation: 27
# Train error: 0.16511993192288368
# Test error: 0.14946063151027345
# Number of epochs with lowest validation: 28
# Train error: 0.15913637354308613
# Test error: 0.1438010205991022
# Number of epochs with lowest validation: 29
# Train error: 0.1534289836057956
# Test error: 0.13840599277372642
# Number of epochs with lowest validation: 30
# Train error: 0.14798413030026034
# Test error: 0.13326212469450663
# Number of epochs with lowest validation: 31
# Train error: 0.14280298586868645
# Test error: 0.12837220239658145
# Number of epochs with lowest validation: 32
# Train error: 0.13787092487016187
# Test error: 0.12372135236256732
# Number of epochs with lowest validation: 33
# Train error: 0.1331655489043356
# Test error: 0.11928720312225849
# Number of epochs with lowest validation: 34
# Train error: 0.12866386030197374
# Test error: 0.11504771447476575
# Number of epochs with lowest validation: 35
# Train error: 0.12437295294468927
# Test error: 0.11101048915683563
# Number of epochs with lowest validation: 36
# Train error: 0.12030489126262746
# Test error: 0.10718771672197136
# Number of epochs with lowest validation: 37
# Train error: 0.11643758601796696
# Test error: 0.10355725443562946
# Number of epochs with lowest validation: 38
# Train error: 0.11273962438120347
# Test error: 0.10008882092079023
# Number of epochs with lowest validation: 39
# Train error: 0.10920439357501628
# Test error: 0.09677592849728496
# Number of epochs with lowest validation: 40
# Train error: 0.1058368001500895
# Test error: 0.09362376248334177
# Number of epochs with lowest validation: 41
# Train error: 0.10264089672657686
# Test error: 0.09063602698201201
# Number of epochs with lowest validation: 42
# Train error: 0.0995908445517524
# Test error: 0.08778781516077919
# Number of epochs with lowest validation: 43
# Train error: 0.0966747627212298
# Test error: 0.08506785591437623
# Number of epochs with lowest validation: 44
# Train error: 0.0939162903620309
# Test error: 0.08249867661639251
# Number of epochs with lowest validation: 45
# Train error: 0.09127169250745613
# Test error: 0.08003847337687754
# Number of epochs with lowest validation: 46
# Train error: 0.08875367456972276
# Test error: 0.07769922798472001
# Number of epochs with lowest validation: 47
# Train error: 0.08635771853022574
# Test error: 0.0754765825737776
# Number of epochs with lowest validation: 48
# Train error: 0.0840719697509694
# Test error: 0.07335921757291883
# Number of epochs with lowest validation: 49
# Train error: 0.08188527993502218
# Test error: 0.07133651151188554
# Number of epochs with lowest validation: 50
# Train error: 0.07981144980203911
# Test error: 0.06942147735799711
# Number of epochs with lowest validation: 51
# Train error: 0.07783275249581723
# Test error: 0.06759720922148038
# Number of epochs with lowest validation: 52
# Train error: 0.07593948332264418
# Test error: 0.06585449759254375
# Number of epochs with lowest validation: 53
# Train error: 0.07415088479041558
# Test error: 0.0642113803408852
# Number of epochs with lowest validation: 54
# Train error: 0.07243929285423757
# Test error: 0.06264156913512416
# Number of epochs with lowest validation: 55
# Train error: 0.0708124876786182
# Test error: 0.061152306865877915
# Number of epochs with lowest validation: 56
# Train error: 0.06925147409132652
# Test error: 0.05972592007645182
# Number of epochs with lowest validation: 57
# Train error: 0.0677894178571324
# Test error: 0.05839294726394948
# Number of epochs with lowest validation: 58
# Train error: 0.06636024592143348
# Test error: 0.05709213231147289
# Number of epochs with lowest validation: 59
# Train error: 0.0650067210049712
# Test error: 0.05586306866921078
# Number of epochs with lowest validation: 60
# Train error: 0.06372145458100965
# Test error: 0.05469856963762864
# Number of epochs with lowest validation: 61
# Train error: 0.06250825430589003
# Test error: 0.053602071492793106
# Number of epochs with lowest validation: 62
# Train error: 0.061322103592983124
# Test error: 0.05253222137456577
# Number of epochs with lowest validation: 63
# Train error: 0.060204947093919964
# Test error: 0.051527176223235535
# Number of epochs with lowest validation: 64
# Train error: 0.05915346972205059
# Test error: 0.050583855466950045
# Number of epochs with lowest validation: 65
# Train error: 0.058139982211194895
# Test error: 0.049676779370557214
# Number of epochs with lowest validation: 66
# Train error: 0.057182619730289715
# Test error: 0.04882237279386133
# Number of epochs with lowest validation: 67
# Train error: 0.05626318401208022
# Test error: 0.048004029407039024
# Number of epochs with lowest validation: 68
# Train error: 0.05538688068036768
# Test error: 0.04722634721011014
# Number of epochs with lowest validation: 69
# Train error: 0.05455979894996994
# Test error: 0.04649465272494133
# Number of epochs with lowest validation: 70
# Train error: 0.05375658711348762
# Test error: 0.04578607705484696
# Number of epochs with lowest validation: 71
# Train error: 0.052998918730530226
# Test error: 0.04511995924416737
# Number of epochs with lowest validation: 72
# Train error: 0.0522691106671955
# Test error: 0.044480375071221843
# Number of epochs with lowest validation: 73
# Train error: 0.051577213720017924
# Test error: 0.04387614747033049
# Number of epochs with lowest validation: 74
# Train error: 0.05092643347752884
# Test error: 0.04330995667081975
# Number of epochs with lowest validation: 75
# Train error: 0.050305717544565746
# Test error: 0.042771988236439074
# Number of epochs with lowest validation: 76
# Train error: 0.049718664832318724
# Test error: 0.04226519738994515
# Number of epochs with lowest validation: 77
# Train error: 0.04914007292861489
# Test error: 0.0417672014948079
# Number of epochs with lowest validation: 78
# Train error: 0.048593772765822274
# Test error: 0.041299026846960095
# Number of epochs with lowest validation: 79
# Train error: 0.04807664100697408
# Test error: 0.040857849231958274
# Number of epochs with lowest validation: 80
# Train error: 0.047584692354901786
# Test error: 0.04043999726211932
# Number of epochs with lowest validation: 81
# Train error: 0.04711549895777651
# Test error: 0.04004328831841887
# Number of epochs with lowest validation: 82
# Train error: 0.04667021238779785
# Test error: 0.039668602746786186
# Number of epochs with lowest validation: 83
# Train error: 0.04624730960868086
# Test error: 0.03931453440536365
# Number of epochs with lowest validation: 84
# Train error: 0.04584604488360102
# Test error: 0.038980385811014824
# Number of epochs with lowest validation: 85
# Train error: 0.04545238303646065
# Test error: 0.03865367429957216
# Number of epochs with lowest validation: 86
# Train error: 0.0450877385114793
# Test error: 0.03835318285828993
# Number of epochs with lowest validation: 87
# Train error: 0.04473237907954452
# Test error: 0.03806153566096394
# Number of epochs with lowest validation: 88
# Train error: 0.044399917628545366
# Test error: 0.037790616940592485
# Number of epochs with lowest validation: 89
# Train error: 0.044080696896064996
# Test error: 0.03753191352276156
# Number of epochs with lowest validation: 90
# Train error: 0.043773104554349816
# Test error: 0.037283924585663646
# Number of epochs with lowest validation: 91
# Train error: 0.04347774379211285
# Test error: 0.037047157638112255
# Train error: 0.03803107629071863
# Test error: 0.034575879949345446
# Number of epochs with lowest validation: 198
# Train error: 0.03803226889194534
# Test error: 0.03457693413869418
# Number of epochs with lowest validation: 198
# Train error: 0.03803314143267684
# Test error: 0.03457765988855074
# Number of epochs with lowest validation: 198
# Train error: 0.03803311462505205
# Test error: 0.03457766640573931
# Number of epochs with lowest validation: 198
# Train error: 0.038028923115364835
# Test error: 0.0345742288664499
# Number of epochs with lowest validation: 198
# Train error: 0.03802606328874895
# Test error: 0.03457190552731828
# Number of epochs with lowest validation: 198
# Train error: 0.03802288652322946
# Test error: 0.034569333314881795
# Number of epochs with lowest validation: 198
# Train error: 0.03802387647727609
# Test error: 0.034570195157620616
# Number of epochs with lowest validation: 198
# Train error: 0.03802394533651512
# Test error: 0.034570256918098764
# Number of epochs with lowest validation: 198
# Train error: 0.03802570121501067
# Test error: 0.03457174068764009
# Number of epochs with lowest validation: 198
# Train error: 0.038028158235201316
# Test error: 0.034573795188592917
# Number of epochs with lowest validation: 198
# Train error: 0.038027467216689495
# Test error: 0.03457328056900009
# Number of epochs with lowest validation: 198
# Train error: 0.03802761690730616
# Test error: 0.034573419137838464
# Number of epochs with lowest validation: 198
# Train error: 0.03802919104389966
# Test error: 0.0345747464475981
# Number of epochs with lowest validation: 198
# Train error: 0.038028392336004815
# Test error: 0.0345740983720969
# Number of epochs with lowest validation: 198
# Train error: 0.03803069502809145
# Test error: 0.03457598372397006
# Number of epochs with lowest validation: 198
# Train error: 0.038029857735772915
# Test error: 0.03457537527372347
# Number of epochs with lowest validation: 198
# Train error: 0.03802992730249227
# Test error: 0.03457541219475285
# Number of epochs with lowest validation: 198
# Train error: 0.038030505744649376
# Test error: 0.03457592050385967
# Number of epochs with lowest validation: 198
# Train error: 0.03803117020488555
# Test error: 0.03457654482865627
# Number of epochs with lowest validation: 198
# Train error: 0.03803498567533343
# Test error: 0.03457972293530279
# Number of epochs with lowest validation: 198
# Train error: 0.038033107287141904
# Test error: 0.034578195181128694
# Number of epochs with lowest validation: 198
# Train error: 0.03803443398138815
# Test error: 0.03457928036265643
# Number of epochs with lowest validation: 198
# Train error: 0.038035584415667435
# Test error: 0.03458027491975148
# Number of epochs with lowest validation: 198
# Train error: 0.0380362107030143
# Test error: 0.034580800178714115
# Number of epochs with lowest validation: 198
# Train error: 0.03803367489339889
# Test error: 0.03457873495412962
# Number of epochs with lowest validation: 198
# Train error: 0.03803277663386191
# Test error: 0.034578028131311916
# Number of epochs with lowest validation: 198
# Train error: 0.03803448177951176
# Test error: 0.034579450778682616
# Final results:
# Training error:0.047374+-0.045500
# Testing error:0.042828+-0.042229

# %%
prediction = res.predict(test_feat)
show_correlation(prediction, test_ranking)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 prediction = res.predict(test_feat)
# ----> 2 show_correlation(prediction, test_ranking)
#
# Cell In[6], line 8, in show_correlation(xs, ys)
#       6 plt.xlabel("Predictions")
#       7 plt.ylabel("Ground truth")
# ----> 8 corr=np.corrcoef([xs,ys])[1,0]
#       9 print("Correlation coefficient:",corr)
#
# File <__array_function__ internals>:200, in corrcoef(*args, **kwargs)
#
# File ~/CHEM277B/msse/lib/python3.10/site-packages/numpy/lib/function_base.py:2846, in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2842 if bias is not np._NoValue or ddof is not np._NoValue:
#    2843     # 2015-03-15, 1.10
#    2844     warnings.warn('bias and ddof have no effect and are deprecated',
#    2845                   DeprecationWarning, stacklevel=3)
# -> 2846 c = cov(x, y, rowvar, dtype=dtype)
#    2847 try:
#    2848     d = diag(c)
#
# File <__array_function__ internals>:200, in cov(*args, **kwargs)
#
# File ~/CHEM277B/msse/lib/python3.10/site-packages/numpy/lib/function_base.py:2616, in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2612     raise ValueError(
#    2613         "ddof must be integer")
#    2615 # Handles complex arrays too
# -> 2616 m = np.asarray(m)
#    2617 if m.ndim > 2:
#    2618     raise ValueError("m has more than 2 dimensions")
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 100) + inhomogeneous part.

# %% [markdown]
# #### Looking at the two graphs provided above, it is clear that removing GRE from the list of features does not affect how accurate the predicition is for the chance of admission. This implies that the weights associated with these features are not large enough to affect the true prediction. Thus, it can be assumed that GRE is not an important feature that needs to be taken into account to determine the chance of admission

# %% [markdown]
# ## 2.Logistic regression using a simple perceptron.
#
# ### For whether your status is sufficient to make it off the Titanic, download the Titanic data set from Files.

# %% [markdown]
# #### a) Process the dataset. What changes from problem 1? Filter out data with missing features. Use one hot encoders to transform the categorical features and the output survival status.
#
#
# #### In this data set, there are some missing features, as noted in the question. Additionally, there are categorical values which were not present in the previous question. I removed some of the features such as the name, ticket, cabin, and passenger id information, which should ideally not affected the prediction in the first place.

# %%
### Read in the titanic dataset ###
titanic=pd.read_csv('titantic.csv')
### Filter out data with missing values 
titanic=titanic.dropna()
### remove name, ticket, cabin, and passenger id
titanic=titanic.drop(['Name','Ticket','Cabin','PassengerId'],axis=1)
titanic.head()
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1          1       1  female  38.0      1      0  71.2833        C
# 3          1       1  female  35.0      1      0  53.1000        S
# 6          0       1    male  54.0      0      0  51.8625        S
# 10         1       3  female   4.0      1      1  16.7000        S
# 11         1       1  female  58.0      0      0  26.5500        S

# %%
## Encode the categorical data Pclass, sex, sibSp, parch, embarked
categorical_feats = titanic[['Pclass','Sex', 'SibSp', 'Parch', 'Embarked']]
continuous_feats = titanic[['Age', 'Fare']]
encoder = OneHotEncoder() 
encoder.fit(categorical_feats)
categorical_feats = encoder.transform(categorical_feats).to_numpy()

survived = np.array(titanic['Survived']).reshape(-1,1)
res_encoder = OneHotEncoder()
survived = res_encoder.fit_transform(survived)
survived = res_encoder.inverse_transform(survived).to_numpy()

### Stack together 
feats = np.hstack((continuous_feats, categorical_feats)) #[  ] [] = [   ]

# %% [markdown]
# ####  b) Use the simple perceptome model we developed in Q1. Use 80% of the data for training and 20% of the data for testing and do 5-fold validation. Can we predict who will survive? Play around with the features to determine which ones give you a better chance to get back to shore.

# %%
train_feat,test_feat,train_ranking,test_ranking=skl_model.train_test_split(feats, survived, test_size = 0.20)
res = Kfold(k=5, Xs=train_feat, ys=train_ranking, epochs=1000)

# %%
prediction = res.predict(test_feat)
show_correlation(prediction, test_ranking)

# %% [markdown]
# ## 3. Nonlinear regression using a simple perceptron and a simple ANN.
#
# ### Let’s try to fit to a simple sine function y = 3 sin(x) + 5 with the simple perceptron and a simple fully connected network.

# %% [markdown]
# #### a) Use the generate_data() function provided in the reference file to generate the training data (5000 points). Do 5-fold cross validation with the simple perceptron model. How well is the prediction? Generate 1000 new points as your test data, and use the show_correlation() function to see how well your model agree with the test data

# %%
def generate_X(number):
    xs=(np.random.random(number)*2-1)*10
    return xs
    
def generate_data(number,stochascity=0.05):
    xs=generate_X(number)
    fs=3*np.sin(xs)-5
    stochastic_ratio=(np.random.random(number)*2-1)*stochascity+1
    return xs,fs*stochastic_ratio

# %%
x,y=generate_data(5000,0.1)
x = x.reshape(-1,1)
y = y.reshape(-1,1)
plt.scatter(x,y,s=0.1)

# %%
## Test using the simple perceptron of 5 fold cross validation 
train_feat,test_feat,train_ranking,test_ranking=skl_model.train_test_split(x, y, test_size = 0.20)
res = Kfold(k=5, Xs=x, ys=y, epochs=100)

# %%
## Generate another 1000 points 
x_new, y_new = generate_data(1000)
prediction = res.predict(x_new)

# %%
## use show_correlation() function 
show_correlation(prediction, y_new)

# %% [markdown]
# #### b) Use the multilayer perceptron regressor of scikit-learn as a simple fully connected neural network. Use one hidden layer with 8 neurons. Do 5-fold cross validation with this simple ANN, and report the MSE on each fold. Visualize the correlation of your model prediction and the true test data.  Is the result better than a simple perceptron?

# %%
### Use mlp regressor to fit the data
from sklearn.neural_network import MLPRegressor

def KFold_NN(k,Xs,ys,hidden_layers,epochs=1000,lr=0.001,):
    # The total number of examples for training the network
    total_num=len(Xs)

    # Built in K-fold function in Sci-Kit Learn
    kf=KFold(n_splits=k,shuffle=True)
    train_error_all=[]
    test_error_all=[]
    for train_selector,test_selector in kf.split(range(total_num)):
        # Decide training examples and testing examples for this fold
        train_Xs=Xs[train_selector]
        test_Xs=Xs[test_selector]
        train_ys=ys[train_selector]
        test_ys=ys[test_selector]
        
        # Establish the model here
        model = MLPRegressor(max_iter=epochs, activation='tanh', early_stopping=True, 
                             validation_fraction=0.25, learning_rate='constant', learning_rate_init=lr,
                             hidden_layer_sizes=hidden_layers).fit(train_Xs, train_ys)
        
        ### Report result for this fold ##
        train_error=model.score(train_Xs,train_ys)
        train_error_all.append(train_error)
        test_error=model.score(test_Xs,test_ys)
        test_error_all.append(test_error)
        print("Train error:",train_error)
        print("Test error:",test_error)

    print("Final results:")
    print("Training error:%f+-%f"%(np.average(train_error_all),np.std(train_error_all)))
    print("Testing error:%f+-%f"%(np.average(test_error_all),np.std(test_error_all)))
    
    # return the last model
    return model

# %%
### Use KFold_NN to fit the data
model=KFold_NN(5,x,y,(8,),epochs=1000,lr=0.001)

# %% [markdown]
# #### c) Play with the architecture for the ANN, can you improve the performance by including additional hidden layers?

# %%
### Use KFold_NN to fit the data
model=KFold_NN(5,x,y,(8,10),epochs=1000,lr=0.001)
